# %%
import pandas as pd

# %%
file_path = 'C:/Users/ASUS/OneDrive/Рабочий стол/PDS/Auto35.xlsx'
df = pd.read_excel(file_path)

df
# Out:
#     N n/n      П.І.П.  Середній бал  Оцінка за поточний екзамен
# 0       1    Аксьонов            70                          80  \
# 1       2    Буханчук            80                          85
# 2       3       Іллюк            75                          82
# 3       4       Кавун            60                          73
# 4       5      Кантур            65                          76
# 5       6   Климовець            85                          78
# 6       7     Колешня            80                          77
# 7       8    Коркушко            67                          90
# 8       9   Кучерявий            70                          91
# 9      10  Межінський            72                          80
# 10     11       Нечай            83                          75
# 11     12       Новик            85                          76
# 12     13   Старовойт            84                          65
# 13     14    Степанюк            90                          78
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[['Середній бал', 'Кількість спроб здати поточний екзамен']]
y = df['Оцінка за поточний екзамен']

# %%
model = LinearRegression()

# %%
scores = cross_val_score(model, X, y, cv=5)

# %%
print("Оцінки моделі: ", scores)
print("Середня оцінка моделі: ", scores.mean())
# Out:
# Оцінки моделі:  [-0.39906361  0.52497124  0.06155289  0.16249856 -1.4218892 ]
# Середня оцінка моделі:  -0.21438602566071854

# %%
file_path = 'C:/Users/ASUS/OneDrive/Рабочий стол/PDS/Auto33.xlsx'
df = pd.read_excel(file_path)

df
# Out:
#     N n/n   Марка авто  Вартість, грн.  Споживання палива, л
# 0       1     Lexus IS         4422189                    80  \
# 1       2     Lexus CT         3121866                    70
# 2       3       Toyota         2425000                    85
# 3       4        Honda         1997230                    73
# 4       5        Skoda          764280                    92
# 5       6  Hyundai i10         1385500                    84
# 6       7  Hyundai i20         2483700                    79
# 7       8    Volswagen          975300                    78
# 8       9     Mercedes         1763200                    89
# 9      10        Mazda          983430                    95
# 10     11          Kia          937600                    94
# 11     12         Audi          829900                    88
#
#     Максимальна швидкість, км/год  Вантажопідйомність, кг
# 0                             350                    2910
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd

# %%
df = pd.DataFrame({
    'Марка авто': ['Lexus IS', 'Lexus CT', 'Toyota', 'Honda', 'Skoda', 'Hyundai i10', 'Hyundai i20', 'Volswagen', 'Mercedes', 'Mazda', 'Kia', 'Audi'],
    'Вартість, грн.': [4422189, 3121866, 2425000, 1997230, 764280, 1385500, 2483700, 975300, 1763200, 983430, 937600, 829900],
    'Споживання палива, л': [80, 70, 85, 73, 92, 84, 79, 78, 89, 95, 94, 88],
    'Максимальна швидкість, км/год': [350, 180, 190, 210, 300, 285, 180, 250, 290, 303, 295, 280],
    'Вантажопідйомність, кг': [2910, 2350, 1800, 1950, 2150, 2835, 1950, 1970, 1834, 1873, 1745, 2400]
})

# %%
X = df[['Споживання палива, л', 'Максимальна швидкість, км/год', 'Вантажопідйомність, кг']]
y = df['Вартість, грн.']

# %%
model = LinearRegression()

# %%
k = 5  
scores = cross_val_score(model, X, y, cv=k, scoring='neg_mean_squared_error')

# %%
mse_scores = -scores

# %%
for i in range(k):
    print(f"Оцінка моделі для розбиття {i+1}: {mse_scores[i]}")
# Out:
# Оцінка моделі для розбиття 1: 6379684655655.8
# Оцінка моделі для розбиття 2: 1434542813915.913
# Оцінка моделі для розбиття 3: 1802352070021.2554
# Оцінка моделі для розбиття 4: 282603301905.6124
# Оцінка моделі для розбиття 5: 576307673363.9932
